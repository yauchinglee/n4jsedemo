# %% [markdown]
# 🌐 Neo4j Management UIs
# Neo4j Browser (Querying): http://localhost:7474
# Use this to run Cypher and view the graph.
# Neo4j Bloom (Discovery): Accessible via the 'Apps' icon in the Browser.
# Use this for your Sales Engineering demo.
# Arrows.app (Modeling): https://arrows.app
# Use this for Task 2 (Graph Modeling).
